# %% [markdown]
# <a href="https://colab.research.google.com/github/moorthy-dnkkw/CSA0645-DAA/blob/main/TOPIC4_PRO_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
l1 = [5, 9, 3]
l2 = [6, 8, 4]
l3 = [7, 6, 5]

total1 = sum(l1)
total2 = sum(l2)
total3 = sum(l3)

ans = min(total1, total2, total3)
print(ans)
# Out:
# 17
