# %% [markdown]
# <a href="https://colab.research.google.com/github/moorthy-dnkkw/CSA0645-DAA/blob/main/TOPIC4_PRO_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%bash
#
# # Save the C code to a file named 'main.c'
# cat << EOF > main.c
# #include <stdio.h>
#
# int main() {
#     printf("This is an\n");
#     printf("example of text\n");
#     printf("justification.\n");
#     return 0;
# }
# EOF
#
# # Compile the C code using gcc
# gcc main.c -o main
#
# # Execute the compiled program
# ./main
# Out:
# This is an
# example of text
# justification.
