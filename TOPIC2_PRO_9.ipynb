# %% [markdown]
# <a href="https://colab.research.google.com/github/moorthy-dnkkw/CSA0645-DAA/blob/main/TOPIC2_PRO_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def string_matching(words):
    result = []
    for i in range(len(words)):
        for j in range(len(words)):
            if i != j and words[i] in words[j]:
                result.append(words[i])
                break
    return result

print(string_matching(["mass","as","hero","superhero"]))
print(string_matching(["leetcode","et","code"]))
print(string_matching(["blue","green","bu"]))
# Out:
# ['as', 'hero']
# ['et', 'code']
# []
