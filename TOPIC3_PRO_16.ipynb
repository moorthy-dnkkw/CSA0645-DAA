# %% [markdown]
# <a href="https://colab.research.google.com/github/moorthy-dnkkw/CSA0645-DAA/blob/main/TOPIC3_PRO_16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#include <stdio.h>

long long multiply(long long x, long long y) {
    return x * y;
}

int main() {
    long long x = 1234;
    long long y = 5678;

    printf("%lld", multiply(x, y));

    return 0;
}
# Out:
#   File "/tmp/ipykernel_1528/2300525846.py", line 3
#     long long multiply(long long x, long long y) {
#          ^
# SyntaxError: invalid syntax

# %%
def multiply(x, y):
    return x * y

# %%
x = 1234
y = 5678

result = multiply(x, y)
print(result)
# Out:
# 7006652
