# %% [markdown]
# <a href="https://colab.research.google.com/github/moorthy-dnkkw/CSA0645-DAA/blob/main/TOPIC2_PRO_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def strStr(haystack, needle):
    return haystack.find(needle)

print(strStr("sadbutsad", "sad"))
print(strStr("leetcode", "leeto"))
# Out:
# 0
# -1
