# %% [markdown]
# <a href="https://colab.research.google.com/github/moorthy-dnkkw/CSA0645-DAA/blob/main/CO5_AT1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
graph = {
    0: [1, 2],
    1: [0, 3],
    2: [0, 3],
    3: [1, 2]
}

vertices = list(graph.keys())
max_set = []

def is_safe(v, current_set):
    for u in current_set:
        if v in graph[u]:
            return False
    return True

def backtrack(index, current_set):
    global max_set

    if index == len(vertices):
        if len(current_set) > len(max_set):
            max_set = current_set[:]
        return

    v = vertices[index]

    # Include vertex if independent
    if is_safe(v, current_set):
        current_set.append(v)
        backtrack(index + 1, current_set)
        current_set.pop()

    # Exclude vertex
    backtrack(index + 1, current_set)

backtrack(0, [])

print("Maximum Independent Set:", max_set)
print("Size:", len(max_set))
# Out:
# Maximum Independent Set: [0, 3]
# Size: 2

# %%
graph = [
    [0, 1, 1, 0, 1],
    [1, 0, 1, 1, 0],
    [1, 1, 0, 1, 1],
    [0, 1, 1, 0, 1],
    [1, 0, 1, 1, 0]
]

n = len(graph)
path = [-1] * n
path[0] = 0

def is_safe(v, pos):
    if graph[path[pos - 1]][v] == 0:
        return False

    if v in path:
        return False

    return True

def hamiltonian(pos):

    if pos == n:
        return graph[path[pos - 1]][path[0]] == 1

    for v in range(1, n):

        if is_safe(v, pos):
            path[pos] = v

            if hamiltonian(pos + 1):
                return True

            path[pos] = -1

    return False

if hamiltonian(1):
    print("Hamiltonian Cycle Exists")
    print(path + [path[0]])
else:
    print("No Hamiltonian Cycle")
# Out:
# Hamiltonian Cycle Exists
# [0, 1, 2, 3, 4, 0]
