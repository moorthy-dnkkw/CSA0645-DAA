# %% [markdown]
# <a href="https://colab.research.google.com/github/moorthy-dnkkw/CSA0645-DAA/blob/main/TOPIC1_PRO_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def findIntersectionValues(nums1, nums2):
    answer1 = sum(1 for x in nums1 if x in nums2)
    answer2 = sum(1 for x in nums2 if x in nums1)
    return [answer1, answer2]

print(findIntersectionValues([2,3,2],[1,2]))
# Out:
# [2, 1]
