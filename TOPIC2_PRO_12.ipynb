# %% [markdown]
# <a href="https://colab.research.google.com/github/moorthy-dnkkw/CSA0645-DAA/blob/main/TOPIC2_PRO_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from itertools import permutations
import math

def distance(a, b):
    return math.dist(a, b)

def tsp(cities):
    start = cities[0]
    min_path = None
    min_dist = float('inf')

    for perm in permutations(cities[1:]):
        path = [start] + list(perm) + [start]
        dist = 0
        for i in range(len(path)-1):
            dist += distance(path[i], path[i+1])

        if dist < min_dist:
            min_dist = dist
            min_path = path

    return min_dist, min_path

cities = [(1,2), (4,5), (7,1), (3,6)]
print(tsp(cities))
# Out:
# (16.969112047670894, [(1, 2), (7, 1), (4, 5), (3, 6), (1, 2)])
