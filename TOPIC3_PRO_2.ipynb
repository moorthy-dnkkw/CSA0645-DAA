# %% [markdown]
# <a href="https://colab.research.google.com/github/moorthy-dnkkw/CSA0645-DAA/blob/main/TOPIC3_PRO_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%bash
# cat <<EOF > cell_B0wB7Rbta2m0.c
# #include <stdio.h>
#
# int main() {
#     int arr[] = {2,4,6,8,10,12,14,18};
#     int n = 8;
#
#     printf("Min = %d\n", arr[0]);
#     printf("Max = %d\n", arr[n-1]);
#
#     return 0;
# }
# EOF
# gcc -Wall -Wextra -std=c99 cell_B0wB7Rbta2m0.c -o cell_B0wB7Rbta2m0 && ./cell_B0wB7Rbta2m0
# Out:
# Min = 2
# Max = 18
