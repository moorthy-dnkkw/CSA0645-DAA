# %% [markdown]
# <a href="https://colab.research.google.com/github/moorthy-dnkkw/CSA0645-DAA/blob/main/TOPIC1_PRO_13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def climbStairs(n):
    if n<=2:
        return n

    a,b=1,2

    for _ in range(3,n+1):
        a,b=b,a+b

    return b

print(climbStairs(4))
# Out:
# 5
