# %% [markdown]
# <a href="https://colab.research.google.com/github/moorthy-dnkkw/CSA0645-DAA/blob/main/TOPIC4_PRO_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile main.c
# #include <stdio.h>
# #include <string.h>
#
# int main() {
#     char s[] = "leetcode";
#     char *dict[] = {"leet", "code"};
#
#     if (strstr(s, "leet") && strstr(s, "code"))
#         printf("true\n"); // Added newline for cleaner output
#     else
#         printf("false\n"); // Added newline for cleaner output
#
#     return 0;
# }
# !gcc main.c -o main
# !./main
# Out:
# Writing main.c
