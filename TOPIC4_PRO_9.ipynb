# %% [markdown]
# <a href="https://colab.research.google.com/github/moorthy-dnkkw/CSA0645-DAA/blob/main/TOPIC4_PRO_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Declare a string variable
s = "ilike"

# Compare the string and print the result
if s == "ilike":
    print("Yes")
else:
    print("No")
# Out:
# Yes
