# %% [markdown]
# <a href="https://colab.research.google.com/github/moorthy-dnkkw/CSA0645-DAA/blob/main/TOPIC1_PRO_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def sortAndFindMax(arr):
    if not arr:
        return None

    arr.sort()
    return arr[-1]

print(sortAndFindMax([3,5,1,4]))
# Out:
# 5
